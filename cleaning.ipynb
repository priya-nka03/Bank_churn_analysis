# %% [markdown]
# Starting cleaning with loading the csv file

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\LENOVO\\Desktop\\pandas\\bank chrun\\Bank_Churn.csv")

# %%
df
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'CustomerId'
# 'Surname'
# 'CreditScore'
# 'Geography'
# 'Gender'
# 'Age'
# 'Tenure'
# 'Balance'
# 'NumOfProducts'
# 'HasCrCard'
# 'IsActiveMember'
# 'EstimatedSalary'
# 'Exited'

# %%
df.isna().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %%
df["CustomerId"]=df["CustomerId"].astype("string")

# %%
df.groupby("Exited")["HasCrCard"].value_counts()
# Out:
# Exited  HasCrCard
# False   True         5631
#         False        2332
# True    True         1424
#         False         613
# Name: count, dtype: int64

# %%
df.groupby("Exited")["HasCrCard"].value_counts(normalize=True)*100
# Out:
# Exited  HasCrCard
# False   True         70.714555
#         False        29.285445
# True    True         69.906726
#         False        30.093274
# Name: proportion, dtype: float64

# %%
df=df.astype({"HasCrCard":bool,"IsActiveMember":bool,"Exited":bool})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  string
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  bool
#  10  IsActiveMember   10000 non-null  bool
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  bool
# dtypes: bool(3), float64(2), int64(4), object(3), string(1)
# memory usage: 810.7+ KB

# %%
df["Age"].describe()
# Out:
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: Age, dtype: float64

# %%
df["Age"].hist()
# Out:
# <Axes: >

# %%
df["Exited"].value_counts()
# Out:
# Exited
# False    7963
# True     2037
# Name: count, dtype: int64

# %%
df["Exited"].value_counts(normalize=True)*100
# Out:
# Exited
# False    79.63
# True     20.37
# Name: proportion, dtype: float64

# %% [markdown]
# 2037(20%) Customers churn the bank

# %%
df["Geography"].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df["Tenure"].value_counts()
# Out:
# Tenure
# 2     1048
# 1     1035
# 7     1028
# 8     1025
# 5     1012
# 3     1009
# 4      989
# 9      984
# 6      967
# 10     490
# 0      413
# Name: count, dtype: int64

# %%
(df["Balance"] == 0).sum()
# Out:
# np.int64(3617)

# %% [markdown]
# Age vs chrun

# %%
df.groupby("Exited")["Age"].mean().sort_values(ascending=False)
# Out:
# Exited
# True     44.837997
# False    37.408389
# Name: Age, dtype: float64

# %%
df.groupby("Gender")["Exited"].value_counts()
# Out:
# Gender  Exited
# Female  False     3404
#         True      1139
# Male    False     4559
#         True       898
# Name: count, dtype: int64

# %%
df.groupby("Gender")["Exited"].value_counts(normalize=True)*100
# Out:
# Gender  Exited
# Female  False     74.928461
#         True      25.071539
# Male    False     83.544072
#         True      16.455928
# Name: proportion, dtype: float64

# %% [markdown]
# Females(1139 , 26%) are most likely to churn the bank as compared to males

# %%
df.groupby("Geography")["Exited"].value_counts()
# Out:
# Geography  Exited
# France     False     4204
#            True       810
# Germany    False     1695
#            True       814
# Spain      False     2064
#            True       413
# Name: count, dtype: int64

# %%
df.groupby("Geography")["Exited"].value_counts(normalize=True)*100
# Out:
# Geography  Exited
# France     False     83.845233
#            True      16.154767
# Germany    False     67.556796
#            True      32.443204
# Spain      False     83.326605
#            True      16.673395
# Name: proportion, dtype: float64

# %%
df.groupby("IsActiveMember")["Exited"].value_counts()
# Out:
# IsActiveMember  Exited
# False           False     3547
#                 True      1302
# True            False     4416
#                 True       735
# Name: count, dtype: int64

# %%
df.groupby("IsActiveMember")["Exited"].value_counts(normalize=True)*100
# Out:
# IsActiveMember  Exited
# False           False     73.149103
#                 True      26.850897
# True            False     85.730926
#                 True      14.269074
# Name: proportion, dtype: float64

# %% [markdown]
# 27% of Non-Active members churn and 14% of Acitve members chrun

# %%
df.to_csv("bank_chunkers.csv",index = False)

# %%
pip install openpyxl
# Out:
# ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  string
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  bool
#  10  IsActiveMember   10000 non-null  bool
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  bool
#  13  CustomerID       10000 non-null  string
# dtypes: bool(3), float64(2), int64(4), object(3), string(2)
# memory usage: 888.8+ KB

# %%
df.groupby("Exited")["Tenure"].mean()
# Out:
# Exited
# False    5.033279
# True     4.932744
# Name: Tenure, dtype: float64

# %%
df.groupby("HasCrCard")["Exited"].value_counts
# Out:
# <bound method SeriesGroupBy.value_counts of <pandas.core.groupby.generic.SeriesGroupBy object at 0x0000028C176C2870>>
