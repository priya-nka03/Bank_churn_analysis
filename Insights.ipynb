# %% [markdown]
# # INSIGHTS
#
# 1.What attributes are more common among churners than non-churners? Can churn be predicted using the variables in the data?

# %% [markdown]
# 44-45 years aged Customers are more likely to churn

# %% [markdown]
# Customer have taken only 1-2 bank products are also churning

# %% [markdown]
# InActive members are most likely to churn as compared to active ones

# %% [markdown]
# Germany and France Customers are contributing more to churn

# %% [markdown]
# Females are more likely to churn

# %% [markdown]
# Customer who chrun was credit card mainly
